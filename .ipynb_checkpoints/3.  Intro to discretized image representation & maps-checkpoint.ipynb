# %% [markdown]
# [Historical dissection discussion]
# [Cartography Metaphor]

# %%
#set some names, because why not

#Path to the repo for this project
repoPath='/Users/plab/Documents/ipynb/'

#file name of standard map of the world
firstMapName='Earthmap1000x500.jpg'

#file name of grayscale map of the world
grayscaleMapName='World_map_blank_without_borders.svg.png'

#file name of world map with "graticule" (lines)
#see https://en.wikipedia.org/wiki/Geographic_coordinate_system for more info
linedMapName='Equirectangular_projection_SW.jpg'

#file name of political world map
politicalMapName='2000px-Dünya.svg.png'


#loading image processing and manipulation package Pillow
# https://pillow.readthedocs.io/en/stable/
import PIL
from PIL import Image
import os
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import numpy as np

firstMapPath=os.path.join(repoPath,'images',firstMapName) 
firstMap= Image.open(firstMapPath)

#in order to display in jupyter, some trickery is necessary
# %matplotlib inline
imshow(np.asarray(firstMap))
fig = plt.gcf()
fig.set_size_inches(15, 30)

# %% [markdown]
# What can we glean from some of the data features of this image?  Lets look at the file type and some of the internal features of the data structure.

# %%
from __future__ import print_function
print(firstMap.format,firstMap.size , firstMap.mode)
print('')

firstMapArray=np.asarray(firstMap)
print('Dimensions of array')
firstMapShape=firstMapArray.shape
print(firstMapShape)
print('')
# Out:
# JPEG (1000, 500) RGB
#
# Dimensions of array
# (500, 1000, 3)

# %% [markdown]
# The first output "JPEG (1000, 500) RGB" provides us with several details.
# JPEG: indicates the file type, which could have also been PNG for example.
# (1000, 500): This quantity indicates the resolution of of the image.  The first number indicates how many pixels wide it is, while the second indicates how tall it is.
#
# The second ouput "(500, 1000, 3)" indicates the actual dimensions of the image's data reprsentation.  Here we see that it is a 3 dimensional array.  Note that the first to values (500 and 1000) correspond to the height and width of the image, but are flipped from the output of the previous report.  This is something to be mindful of when investigating data structures as the norms for ordering dimensions vary from function to function and programming language to programming language.  The final value (3) is something new though.  This corresponds to the color channels for the image.  Here we see that there are three of these channels and they correspond to to the Red (R), Green (G), and Blue (B) channels of the JPEG image.  Had the final entry of the first output been CMYK (Cyan Magenta Yellow Black) the size of the final dimension would have been 4 instead of 3.  Typically though, CMYK is used for printed (or to be printed) mediums.
#
# Now that we know how the image's data is arranged, we can ask what is in a specific a specific data entry in the array, for example the values associated with [0,0] (which we would expect to have 3 values, due to the RGB).
# [Whats in a specific pixel?]

# %%
print('Upper left pixel')
print(firstMapArray[0,0])
print('')
print('Atlantic pixel')
print(firstMapArray[150,400])
print('')
print('US pixel')
print(firstMapArray[150,250])
print('')
print('Russia pixel')
print(firstMapArray[80,700])
print('')
print('North Africa pixel')
print(firstMapArray[180,550])
print('')
# Out:
# Upper left pixel
# [214 213 227]
#
# Atlantic pixel
# [ 24  74 101]
#
# US pixel
# [122 118  73]
#
# Russia pixel
# [65 74 45]
#
# North Africa pixel
# [204 170 125]

# %% [markdown]
# Above we have querried the entries for the following pixels:
#
# [0,0], which is the upper leftmost pixel
# [150,400], which is in the Atlantic
# [150,250], which is in the middle of the United States
# [80,700], which is in western Russia
# [180,550], which is in north Africa
#
# For each of these pixels we have obtained a 1 by 3 output, which corresponds to the RGB value for each pixel.  To check what colors these are associated with, find an online RGB color picker (i.e. https://www.rapidtables.com/web/color/RGB_Color.html) and type in the values.
#
# You should get approximately the following colors:
#
# upper leftmost pixel            : White
# Atlantic                        : Blue
# middle of the United States     : Yellow
# western Russia                  : Green
# north Africa                    : Orange
#
# Given what the JPEG map is of (a geographic sattelite map of the world) these colors correspond to the color (refleted visible light) of a specific area on the surface of the earth.  We can infer the type of biome associated with that location from this color
#
# upper leftmost pixel            : White     ->  Ice
# Atlantic                        : Blue      ->  Ocean
# middle of the United States     : Yellow    ->  Plains
# western Russia                  : Green     ->  Forests
# north Africa                    : Orange    ->  Desert

# %% [markdown]
# [note clusters of colors
# [Say we were interested in ocean vs land]

# %%
import numpy as np
import matplotlib.pyplot as plt

# a naieve mask for the ocean
print('Atlantic pixel')
atlanticColor=firstMapArray[150,400]
print(atlanticColor)
print('')

atlanticColor=[ 24,74,101]

#quick and dirty hypoteuse algorithm
def multiDHypot(coords1,coords2):
    dimDisplace=np.subtract(coords1,coords2)
    elementNum=dimDisplace.size
    elementSquare=np.square(dimDisplace)
    elementSquareSum=np.sum(elementSquare)
    if elementNum==2:
        hypotLeng=np.sqrt(elementSquareSum)
    elif elementNum==3:
        hypotLeng=np.cbrt(elementSquareSum)
    return hypotLeng


colorDistMeasures=np.zeros(([firstMapShape[0],firstMapShape[1]]))

for iRows in range(firstMapShape[0]):
    for iColumns in range(firstMapShape[1]):
        curPixelVal=firstMapArray[iRows,iColumns]
        colorDistMeasures[iRows,iColumns]=multiDHypot(curPixelVal,atlanticColor)

flattenedDistances=np.ndarray.flatten(colorDistMeasures)
        
plt.hist(flattenedDistances, bins=100)
plt.xlabel('Distance from ocean color')
plt.ylabel('Number of pixels')
plt.title('Distributon of RGB color distance from Atlantic pixel color')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)


CutoffDistanceValue=12
naieveOceanMask=colorDistMeasures<CutoffDistanceValue
# Out:
# Atlantic pixel
# [ 24  74 101]

# %%
imshow(naieveOceanMask)
fig = plt.gcf()
fig.set_size_inches(15, 30)

# %% [markdown]
# Kind of looks like what you might obtain directly from the internet

# %%
grayscaleMapPath=os.path.join(repoPath,'images',grayscaleMapName) 
grayscaleMap= Image.open(grayscaleMapPath)
print(grayscaleMap.format,grayscaleMap.size , grayscaleMap.mode)
print('')

#quick computation to obtain native aspect ratio approximation relative to preeceding image's 2:1
grayscaleMapApsectRatio=4378/2435
print('Ratio of width to height')
print(grayscaleMapApsectRatio)
print('')

#in order to display in jupyter, some trickery is necessary
# %matplotlib inline
imshow(np.asarray(grayscaleMap))
fig = plt.gcf()
fig.set_size_inches(15, grayscaleMapApsectRatio*15)
# Out:
# PNG (4378, 2435) RGBA
#
# Ratio of width to height
# 1.797946611909651

# %% [markdown]
# What if we want to compare the two maps, we need to ensure they are the same size

# %%
grayscaleResized=grayscaleMap.resize([firstMapShape[1],firstMapShape[0]], resample=0)
# %matplotlib inline
grayscaleResizedData=np.asarray(grayscaleResized)
imshow(np.asarray(grayscaleResizedData))
fig = plt.gcf()
fig.set_size_inches(15, 30)
print(grayscaleResizedData[0,0])
# Out:
# [0 0 0 0]

# %%
colorDistMeasures=np.zeros(([firstMapShape[0],firstMapShape[1]]))

for iRows in range(firstMapShape[0]):
    for iColumns in range(firstMapShape[1]):
        curPixelVal=grayscaleResizedData[iRows,iColumns]
        #the sum of 4 zeros is zero
        colorDistMeasures[iRows,iColumns]=np.sum(curPixelVal)==0

imshow(colorDistMeasures)
fig = plt.gcf()
fig.set_size_inches(15, 30)

# %% [markdown]
# Where are the discrepancies in our maps?

# %%
discrepancyMapping=np.logical_xor(colorDistMeasures,naieveOceanMask)

imshow(discrepancyMapping)
fig = plt.gcf()
fig.set_size_inches(15, 30)

# %% [markdown]
# Appears to be a shifting between the two images

# %%
linedMapPath=os.path.join(repoPath,'images',linedMapName) 
linedMap= Image.open(linedMapPath)
print(linedMap.format,linedMap.size , linedMap.mode)
print('')
#not exactly a 2:1 aspect ratio, but almost
linedMapData=np.asarray(linedMap)
imshow(linedMapData)
fig = plt.gcf()
fig.set_size_inches(15, 30)
# Out:
# JPEG (2058, 1036) RGB

# %%
linedMapData=np.asarray(linedMap)
waterColor=linedMapData[500,500]
print('Lined map water color')
print(waterColor)
print('')

zeroPointColor=linedMapData[1024,517]
print(zeroPointColor)

linedMapResized=linedMap.resize([firstMapShape[1],firstMapShape[0]], resample=0)
linedMapResizedData=np.asarray(linedMapResized)


colorDistMeasures=np.zeros(([firstMapShape[0],firstMapShape[1]]))

for iRows in range(firstMapShape[0]):
    for iColumns in range(firstMapShape[1]):
        curPixelVal=linedMapResizedData[iRows,iColumns]
        colorDistMeasures[iRows,iColumns]=multiDHypot(curPixelVal,waterColor)

CutoffDistanceValue=1
linedOceanMask=colorDistMeasures<CutoffDistanceValue

imshow(np.asarray(linedOceanMask))
fig = plt.gcf()
fig.set_size_inches(15, 30)
# Out:
# Lined map water color
# [ 54 140 173]
#
# [228 228 228]

# %%
linedZoom=linedMapResizedData[200:300,450:550,:]
imshow(linedZoom)
fig = plt.gcf()
fig.set_size_inches(30, 30)

#center coord
centerLinedResizedCoord=[250,500]

# %% [markdown]
# now try and align the quick and dirty ocean mask to the lined map

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import IntSlider

def plot_mapDiscrepancy(map1,map2): 
    discrepancyMapping=np.logical_xor(map1,map2)
    # %matplotlib inline
    imshow(discrepancyMapping)
    fig = plt.gcf()
    fig.set_size_inches(15, 30)
    
def update(xOffset, yOffset):
    naieveOceanMaskMoved = np.roll(naieveOceanMask,xOffset,0)
    naieveOceanMaskMoved = np.roll(naieveOceanMaskMoved,yOffset,1)
    plot_mapDiscrepancy(linedOceanMask,naieveOceanMaskMoved)

interact(update, xOffset=IntSlider(min=-30, max=30, step=1,continuous_update=False),  yOffset=IntSlider(min=-30, max=30, step=1,continuous_update=False))
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='xOffset', max=30, min=-30), Int…
# <function __main__.update(xOffset, yOffset)>
